# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.transfermarkt.com/manchester-city/startseite/verein/281?saison_id=2022"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)

# %%
# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
# ...

# %%
player_elements = soup.find_all("span", class_="show-for-small")

# %%
player_href = "/josh-wilson-esbrand/marktwertverlauf/spieler/576121"

# %%
soup2 = BeautifulSoup(player_href, "html.parser")
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
player_value = soup.findAll("a", href=player_href)

# %%
for value in player_value:
    print(value, end="\n"*2)
# Out:
# <a href="/josh-wilson-esbrand/marktwertverlauf/spieler/576121">€1.50m</a>

# %%
print(player_value[0].text.strip())
# Out:
# €1.50m

# %%
for fact in facts_data:
    print(fact, end="\n"*2)

# %%
# Create lists to store the extracted player information
player_names = []
player_hrefs = []

# %%
import pandas as pd
import numpy as np

# %%
# Iterate over the player elements and extract the player name and href
for player in player_elements:
    # Extract the player name
    player_name = player.text.strip()

    # Extract the href link
    player_href = player.find("a")["href"]

    player_names.append(player_name)
    player_hrefs.append(player_href)

# %%
# Create a DataFrame from the extracted player information
data = {
    "Player Name": player_names,
    "Href": player_hrefs
}

df = pd.DataFrame(data)

# %%
# Print the DataFrame
print(df)
# Out:
#           Player Name                                        Href
# 0             Ederson              /ederson/profil/spieler/238223
# 1           S. Ortega         /stefan-ortega/profil/spieler/85941
# 2          Z. Steffen         /zack-steffen/profil/spieler/221624
# 3           S. Carson          /scott-carson/profil/spieler/14555
# 4             R. Dias           /ruben-dias/profil/spieler/258004
# 5              N. Aké           /nathan-ake/profil/spieler/177476
# 6           J. Stones          /john-stones/profil/spieler/186590
# 7           M. Akanji        /manuel-akanji/profil/spieler/284730
# 8          A. Laporte      /aymeric-laporte/profil/spieler/176553
# 9            L. Mbete           /luke-mbete/profil/spieler/609883
# 10           S. Gómez         /sergio-gomez/profil/spieler/366930
# 11  J. Wilson-Esbrand  /josh-wilson-esbrand/profil/spieler/576121
# 12           B. Mendy       /benjamin-mendy/profil/spieler/157495
# ...
